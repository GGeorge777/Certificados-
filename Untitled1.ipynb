# %% [markdown]
# <a href="https://colab.research.google.com/github/GGeorge777/Certificados-/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def contaRegressiva(N=30):
  while(N):
    print(N)
    print(n)
    n=n-1
  if n== 0:
    print('recolar')
  else:
    print(n)
    #Ex2
def contRegressiva(N=5):
  while(N):
    print(N)
    N= N-1
contRegressiva(5)
print('decolar!')
